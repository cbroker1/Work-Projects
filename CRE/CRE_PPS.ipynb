# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
df = pd.read_csv(r'C:\Users\cbroker1\Desktop\intake.csv', low_memory=False)

# %%
pd.set_option('display.max_rows', None)
df.dtypes
# Out:
# fldIntakeId                                        int64
# fldCaseId                                          int64
# fldStaffId                                        object
# fldFormDate                                       object
# fldJHEDID                                         object
# fldClientId                                        int64
# fldReferredById                                    int64
# fldAge                                             int64
# fldRace                                            int64
# fldGender                                         object
# fldMaritalStatus                                   int64
# fldJHAffiliation                                   int64
# fldPresentingProblemNotes                         object
# fldCollaborativeInfoNotes                         object
# fldProblemsDuringGestation                         int64
# fldProblemsDuringBirth                             int64
# ...
